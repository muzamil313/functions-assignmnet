# %% [markdown]
# Functions assignment
#
# # What are data structures, and why are they important?
# - Data structureis a way of organising,processing,and storing data in a computer effeciently.after it is stored effeciently it is manupulated efficiently by computer .some eg's of data struture are lists,tupples,sets,strings,dictionary.They are important because they help us to they help us organise, performance and manipulation data of data effeciently
#
# # Explain the difference between mutable and immutable data types with examples
# - Mutable data types can be changed after creation.  we can modify them by adding, removing elements whenever needed.Examples are list , dictionary, sets.
# Immutable data types cannot be changes once they are created. exampes are integers(int), strings ,tupples
#
# #What are the main differences between lists and tuples in Python?
# - The main difference between lists and tuples is given as
# list can be modified while as tupple cannot be modified.
# the syntax used in list is [ ] while s
# The syntax used in tupple is ( )
#
# # Describe how dictionaries store data?
# - the dictionary stores data as key value pairs. Each key must be unique and and immutable. The value can beof any data type.when a key is added to a dictionary it uses a hash function to convert the key into unique hash code
#
# # Why might you use a set instead of a list in Python?
# - we may use set instead of list because set has no duplicate elements ,fast membership testing, set operations which help us to store and manipulate data effeciently.
# # What is a string in Python, and how is it different from a list?
# - A string is a sequence of characters enclosed in quotes (single',double",or triple'''/""").It is different from list as list stores sequence of data types enclosed in square bracket while string is sequence of characters enclosed in quotes.
# # How do tuples ensure data integrity in Python?
# - Once a tuple is created, its elements cannot be modified, added, or removed. This characteristic ensures that the data remains consistent throughout the program, reducing the risk of bugs caused by unintended modification.
# # What is a hash table, and how does it relate to dictionaries in Python?
# - A hash table uses a hash function to compute an index (also known as a hash code) into an array of buckets or slots, from which the desired value can be found. This process allows for average-case constant time complexity, O(1), for operations like insertion, deletion, and lookup.
# # can lists contain different data types in Python?
# - Yes, Python lists can contain elements of different data types. This flexibility is a core feature of Python's dynamic typing system.Example
# mixed_list = [42, "hello", 3.14, True, [1, 2], {"key": "value"}].In this example, mixed_list contains:
#
# An integer (42)
# A string ("hello")
# A float (3.14)
# A boolean (True)
# A nested list ([1, 2])
# A dictionary ({"key": "value"})
# # Explain why strings are immutable in Python?
# - In Python, strings are immutable, meaning once a string is created, it cannot be altered. Any operation that seems to modify a string actually creates a new string object. This design choice offers several advantages: Thread safety,memory effeciency,effecient memory management etc.
# #  What advantages do dictionaries offer over lists for certain tasks?
# - Dictionaries in Python offer several advantages over lists for specific tasks, particularly when dealing with key-value associations and requiring efficient data retrieval. Here's how dictionaries can be more beneficial than lists in certain scenarios: fast look ups by key,data organisation with key value pairs,efecient deletion and assertion
#
# # Describe a scenario where using a tuple would be preferable over a list?
# - A scenario where using a tuple is preferable over a list in Python is when you need to store a collection of values that should remain constant throughout the program's execution.
# #  How do sets handle duplicate values in Python?
# - In Python , sets automatically eliminate duplicate values, ensuring that each element within a set is unique. This behavior is intrinsic to the set data structure, which is designed to store unordered collections of distinct elements.
# #  How does the “in” keyword work differently for lists and dictionaries?
# - In list keyword "in" checks whether a specific values is in list or not.
# while in dictionary it checks whether a specific key exist in dictionary.
# # Can you modify the elements of a tuple? Explain why or why not?
# - Tuples are designed to be immutable for several reasons:
#
# Data Integrity: Immutability ensures that the data remains constant throughout the program, preventing accidental modifications.
#
# Hashability: Immutable objects can be hashed, allowing tuples to be used as keys in dictionaries and elements in sets.
#
# Performance Optimization: Knowing that an object won't change allows Python to make performance optimizations, such as interning and memory sharing.
# # What is a nested dictionary, and give an example of its use case?
# - A nested dictionary is essentially a dictionary within a dictionary. Each key in the outer dictionary maps to another dictionary as its value.
#
# # Describe the time complexity of accessing elements in a dictionary?
# - In Python, accessing elements in a dictionary by key is highly efficient due to the underlying hash table implementation.
#
# Average Case: Accessing a value by its key has a time complexity of O(1). This means that the operation takes constant time, regardless of the size of the dictionary.
#
# Worst Case: In rare scenarios involving many hash collisions, the time complexity can degrade to O(n), where n is the number of elements in the dictionary. However, Python's hash functions and collision resolution strategies are designed to minimize such occurrences.
# #  In what situations are lists preferred over dictionaries?
# - In Python, lists are preferred over dictionaries in scenarios where the data's order, sequence, or positional indexing is crucial. Here are some situations where using a list is more appropriate:
#
#  1. Maintaining Order and Sequence
#  2. Accessing Elements by Position
#  3. Allowing Duplicate Elements
#  4. Iterating in a Specific Order
#
#  # Why are dictionaries considered unordered, and how does that affect data retrieval?
#  - In Python, dictionaries are collections of key-value pairs. Their ordering behavior has evolved over different Python versions, impacting how data is retrieved and iterated.
#
#
# #  Explain the difference between a list and a dictionary in terms of data retrieval.
#  - Lists are ordered sequences of elements, indexed by integers starting from 0.
# Access Method: Elements are retrieved using their positional index.
#
# while as dictionary store data as key-value pairs, allowing for the association of unique keys with specific values.
# Acess Method:Elements are retrieved using their unique keys.

# %%
# Write a code to create a string with your name and print it.
name = "muzamil"
print(name)
# Out:
# muzamil

# %%
# Write a code to find the length of the string "Hello World"
text = "Hello World"
print(len(text))
# Out:
# 11

# %%
#Write a code to slice the first 3 characters from the string "Python Programming"
text = "python programming"
print(text[0:3])
# Out:
# pyt

# %%
#Write a code to convert the string "hello" to uppercase
text = "hello"
print(text.upper())
# Out:
# HELLO

# %%
#Write a code to replace the word "apple" with "orange" in the string "I like apple"
sentence = "i like apple"
sentence
# Out:
# 'i like apple'

# %%
sentence1 = sentence .replace("apple","orange")
sentence1
# Out:
# 'i like orange'

# %%
# Write a code to create a list with numbers 1 to 5 and print it
numbers = list (range(1,6))
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
# Write a code to append the number 10 to the list [1, 2, 3, 4].
listt = [1, 2, 3, 4]
listt.append(10)
listt
# Out:
# [1, 2, 3, 4, 10]

# %%
# Write a code to remove the number 3 from the list [1, 2, 3, 4, 5].
listt = [1,2,3,4,5]
listt.remove(3)
listt
# Out:
# [1, 2, 4, 5]

# %%
#Write a code to access the second element in the list ['a', 'b', 'c', 'd'].
list1 = ['a', 'b', 'c', 'd']
list1
# Out:
# ['a', 'b', 'c', 'd']

# %%
list1[1]
# Out:
# 'b'

# %%
 # Write a code to reverse the list [10, 20, 30, 40, 50].
 list2 = [10, 20, 30, 40, 50]
 list3 = list2[::-1]
 list3
# Out:
# [50, 40, 30, 20, 10]

# %%
#. Write a code to create a tuple with the elements 100, 200, 300 and print it.
tupple = (100, 200, 300)
print(tupple)
# Out:
# (100, 200, 300)

# %%
# Write a code to access the second-to-last element of the tuple ('red', 'green', 'blue', 'yellow').
colors = ("red", "green", "blue", "yellow")
colors
# Out:
# ('red', 'green', 'blue', 'yellow')

# %%
colors[-2]
# Out:
# 'blue'

# %%
# Write a code to find the minimum number in the tuple (10, 20, 5, 15).
numbers = (10, 20, 5, 15)
min(numbers)
# Out:
# 5

# %%
# Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').
animals = ('dog', 'cat', 'rabbit')
animals.index("cat")
# Out:
# 1

# %%
# Write a code to create a tuple containing three different fruits and check if "kiwi" is in it
fruits = ("apple", "banana", "orange")
"kiwi" in fruits
# Out:
# False

# %%
fruits1 = ("apple","kiwi", "orange")
"kiwi" in fruits1
# Out:
# True

# %%
# Write a code to create a set with the elements 'a', 'b', 'c' and print it
set1 = {"a", "b", "c"}
print(set1)
# Out:
# {'a', 'b', 'c'}

# %%
# Write a code to clear all elements from the set {1, 2, 3, 4, 5}.
set2 = {1, 2, 3, 4, 5}
set2.clear()
set2     # set reamins as it is created but its elements are cleared
# Out:
# set()

# %%
#Write a code to remove the element 4 from the set {1, 2, 3, 4}.
set3 = {1, 2, 3, 4}
set3.remove(4)
set3
# Out:
# {1, 2, 3}

# %%
#. Write a code to find the union of two sets {1, 2, 3} and {3, 4, 5}
set4 = {1, 2, 3}
set5 = {3, 4, 5}
set4.union(set5)
# Out:
# {1, 2, 3, 4, 5}

# %%
#Write a code to find the intersection of two sets {1, 2, 3} and {2, 3, 4}.
set6 = {1, 2, 3}
set7 = {2, 3, 4}
set6.intersection(set7)
# Out:
# {2, 3}

# %%
# Write a code to create a dictionary with the keys "name", "age", and "city", and print it.
my_dict = {"name": "muzamil", "age": 23, "city": "srinagar"}
print(my_dict)
# Out:
# {'name': 'muzamil', 'age': 23, 'city': 'srinagar'}

# %%
#Write a code to add a new key-value pair "country": "USA" to the dictionary {'name': 'John', 'age': 25}.
my_dict = {'name': 'John', 'age': 25}
my_dict
# Out:
# {'name': 'John', 'age': 25}

# %%
my_dict["country"] = "USA"
my_dict
# Out:
# {'name': 'John', 'age': 25, 'country': 'USA'}

# %%
# Write a code to access the value associated with the key "name" in the dictionary {'name': 'Alice', 'age': 30}.
my_dict = {'name': 'Alice', 'age': 30}
my_dict
# Out:
# {'name': 'Alice', 'age': 30}

# %%
my_dict["name"]
# Out:
# 'Alice'

# %%
# Write a code to access the value associated with the key "name" in the dictionary {'name': 'Alice', 'age': 30}
my_dict = {'name': 'Alice', 'age': 30}
my_dict
# Out:
# {'name': 'Alice', 'age': 30}

# %%
my_dict['name']
# Out:
# 'Alice'

# %%
#. Write a code to remove the key "age" from the dictionary {'name': 'Bob', 'age': 22, 'city': 'New York'}.
my_dict = {'name': 'Bob', 'age': 22, 'city': 'New York'}
my_dict
# Out:
# {'name': 'Bob', 'age': 22, 'city': 'New York'}

# %%
my_dict2 = my_dict.pop("age")
my_dict2
# Out:
# 22

# %%
my_dict2
# Out:
# 22

# %%
# Write a code to check if the key "city" exists in the dictionary {'name': 'Alice', 'city': 'Paris'}.
my_dict = {'name': 'Alice', 'city': 'Paris'}
my_dict
# Out:
# {'name': 'Alice', 'city': 'Paris'}

# %%
my_dict["city"]
# Out:
# 'Paris'

# %%
# Write a code to create a list, a tuple, and a dictionary, and print them all
list1 = [1,2,3,4]
print(list1)
# Out:
# [1, 2, 3, 4]

# %%
tuple = (1,2,3,4)
print(tuple)
# Out:
# (1, 2, 3, 4)

# %%
Dict = {"name": "muzamil", "age": 23, "city": "srinagar"}
print(Dict)
# Out:
# {'name': 'muzamil', 'age': 23, 'city': 'srinagar'}

# %%
 #Write a code to create a list of 5 random numbers between 1 and 100, sort it in ascending order, and print the ressult.(replaced).
import random
random_numbers = [random.randint(1, 100) for _ in range(5)]
random_numbers
# Out:
# [83, 33, 36, 83, 66]

# %%
# Write a code to create a list with strings and print the element at the third index
fruits = ["apple", "banana", "cherry", "date", "elderberry"]
print("Element at index 3:", fruits[3])
# Out:
# Element at index 3: date

# %%
#. Write a code to combine two dictionaries into one and print the result.
dict1 = {'a': 1, 'b': 2}
dict2 = {'c': 3, 'd': 4}
combined_dict = {**dict1, **dict2}
print(combined_dict)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
#Write a code to convert a list of strings into a set
string_list = ["apple", "banana", "apple", "cherry", "banana"]
string_set = set(string_list)
print(string_set)
# Out:
# {'banana', 'cherry', 'apple'}
